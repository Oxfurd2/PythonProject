# %%
#Extracting Stock Data using Python TSLA

# %%
#Question 1: Use yfinance to Extract Stock Data
#Reset the index, save, and display the first five rows of the tesla_data dataframe using the head function. 
#Upload a screenshot of the results and code from the beginning of Question 1 to the results below.

import yfinance as yf
import pandas as pd

# Download Tesla stock data using yfinance
tesla_data = yf.download('TSLA', start='2010-01-01', end='2024-12-31')

tesla_data.reset_index(inplace=True)

print(tesla_data.head())
# Out:
# C:\Users\sandr\AppData\Local\Temp\ipykernel_23184\3723791404.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   tesla_data = yf.download('TSLA', start='2010-01-01', end='2024-12-31')
# [*********************100%***********************]  1 of 1 completed
# Price        Date     Close      High       Low      Open     Volume
# Ticker                 TSLA      TSLA      TSLA      TSLA       TSLA
# 0      2010-06-29  1.592667  1.666667  1.169333  1.266667  281494500
# 1      2010-06-30  1.588667  2.028000  1.553333  1.719333  257806500
# 2      2010-07-01  1.464000  1.728000  1.351333  1.666667  123282000
# 3      2010-07-02  1.280000  1.540000  1.247333  1.533333   77097000
# 4      2010-07-06  1.074000  1.333333  1.055333  1.333333  103003500

# %%
#Question 2: Use Webscraping to Extract Tesla Revenue Data
#Display the last five rows of the tesla_revenue dataframe using the tail function. Upload a screenshot of the results
import pandas as pd
import requests

# Step 1: Download the HTML page
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/revenue.htm"
html_data = requests.get(url).text

tables = pd.read_html(html_data)

tesla_revenue = tables[1]

tesla_revenue.columns = ['Date', 'Revenue']

tesla_revenue = tesla_revenue[tesla_revenue['Revenue'] != '']

print(tesla_revenue.tail())
# Out:
#           Date Revenue
# 49  2010-06-30     $28
# 50  2010-03-31     $21
# 51  2009-12-31     NaN
# 52  2009-09-30     $46
# 53  2009-06-30     $27
# C:\Users\sandr\AppData\Local\Temp\ipykernel_23184\4232584415.py:10: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html_data)

# %%
#Question 3: Use yfinance to Extract Stock Data
#Reset the index, save, and display the first five rows of the gme_data dataframe using the head function. 
#Upload a screenshot of the results and code from the beginning of Question 1 to the results below.
import yfinance as yf
import pandas as pd

# Step 1: Download GME stock data using yfinance
gme_data = yf.download('GME', start='2010-01-01', end='2024-12-31')

gme_data.reset_index(inplace=True)

print(gme_data.head())
# Out:
# C:\Users\sandr\AppData\Local\Temp\ipykernel_23184\2617094559.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   gme_data = yf.download('GME', start='2010-01-01', end='2024-12-31')
# [*********************100%***********************]  1 of 1 completed
# Price        Date     Close      High       Low      Open     Volume
# Ticker                  GME       GME       GME       GME        GME
# 0      2010-01-04  3.854643  3.863060  3.703151  3.714934   26702800
# 1      2010-01-05  3.959005  3.996036  3.854643  3.856327   21269600
# 2      2010-01-06  4.044851  4.056634  3.908508  3.948906   21471200
# 3      2010-01-07  3.443929  3.563440  3.268872  3.368183  164761200
# 4      2010-01-08  3.415315  3.573541  3.405216  3.474229   47872400

# %%
#Question 4: Use Webscraping to Extract GME Revenue Data
#Display the last five rows of the gme_revenue dataframe using the tail function. Upload a screenshot of the results.
import pandas as pd
import requests

# Step 1: Download the webpage containing GME revenue data
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/revenue.htm"
html_data = requests.get(url).text

tables = pd.read_html(html_data)

gme_revenue = tables[2]

# Select only the first two columns and rename them
gme_revenue = gme_revenue.iloc[:, :2]
gme_revenue.columns = ['Date', 'Revenue']

gme_revenue = gme_revenue[gme_revenue['Revenue'] != '']

print(gme_revenue.tail())
# Out:
#                                                 Date  \
# 0                                  Auto/Tires/Trucks
# 1  Tesla is the market leader in battery-powered ...
#
#                                              Revenue
# 0                      Auto Manufacturers - Domestic
# 1  Tesla is the market leader in battery-powered ...
# C:\Users\sandr\AppData\Local\Temp\ipykernel_24948\3497248961.py:10: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html_data)

# %%
#Question 5: Plot Tesla Stock Graph
#Use the make_graph function to graph the Tesla Stock Data, also provide a title for the graph.
#Upload a screenshot of your results.

import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
# Download Tesla stock data using yfinance
tesla_data = yf.download('TSLA', start='2010-01-01', end='2024-12-31')

tesla_data.reset_index(inplace=True)

print(tesla_data.head())


# Define a function to plot stock data
def make_graph(data, stock, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data['Date'], data['Close'], label=f'{stock} Stock Price', color='blue')
    plt.xlabel('Date')
    plt.ylabel('Closing Price (USD)')
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# Call the function with Tesla data
make_graph(tesla_data, 'Tesla', 'Tesla Stock Price Over Time')
# Out:
# C:\Users\sandr\AppData\Local\Temp\ipykernel_24948\3623747396.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   tesla_data = yf.download('TSLA', start='2010-01-01', end='2024-12-31')
# [*********************100%***********************]  1 of 1 completed
# Price        Date     Close      High       Low      Open     Volume
# Ticker                 TSLA      TSLA      TSLA      TSLA       TSLA
# 0      2010-06-29  1.592667  1.666667  1.169333  1.266667  281494500
# 1      2010-06-30  1.588667  2.028000  1.553333  1.719333  257806500
# 2      2010-07-01  1.464000  1.728000  1.351333  1.666667  123282000
# 3      2010-07-02  1.280000  1.540000  1.247333  1.533333   77097000
# 4      2010-07-06  1.074000  1.333333  1.055333  1.333333  103003500

# %%
#Question 6: Plot GameStop Stock Graph
#Use the make_graph function to graph the GameStop Stock Data, also provide a title for the graph.
#Upload a screenshot of your results.
import yfinance as yf
import pandas as pd

# Step 1: Download GME stock data using yfinance
gme_data = yf.download('GME', start='2010-01-01', end='2024-12-31')

gme_data.reset_index(inplace=True)

print(gme_data.head())
import matplotlib.pyplot as plt

# If make_graph is not already defined, define it here again
def make_graph(data, stock, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data['Date'], data['Close'], label=f'{stock} Stock Price', color='green')
    plt.xlabel('Date')
    plt.ylabel('Closing Price (USD)')
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
make_graph(gme_data, 'GameStop', 'GameStop Stock Price Over Time')
# Out:
# C:\Users\sandr\AppData\Local\Temp\ipykernel_24948\1913509161.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   gme_data = yf.download('GME', start='2010-01-01', end='2024-12-31')
# [*********************100%***********************]  1 of 1 completed
# Price        Date     Close      High       Low      Open     Volume
# Ticker                  GME       GME       GME       GME        GME
# 0      2010-01-04  3.854644  3.863060  3.703151  3.714934   26702800
# 1      2010-01-05  3.959004  3.996036  3.854643  3.856326   21269600
# 2      2010-01-06  4.044851  4.056634  3.908508  3.948906   21471200
# 3      2010-01-07  3.443930  3.563441  3.268872  3.368184  164761200
# 4      2010-01-08  3.415316  3.573541  3.405216  3.474229   47872400
